# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
clima = pd.read_csv('../data/clima.csv', index_col=0)
ine_pernoctaciones=pd.read_csv('../data/ine_pernoctaciones.csv', index_col=0)
ine_viajeros=pd.read_csv('../data/ine_viajeros.csv', index_col=0)
ine_total=pd.read_csv('../data/ine_total.csv', index_col=0)
ign= pd.read_csv('../data/IGN.csv', index_col=0)

# %%
clima.columns
# Out:
# Index(['Provincia', 'Periodo', 'Media_tmed', 'Media_prec', 'Media_sol',
#        'Media_tmin', 'Media_tmax', 'ID_total'],
#       dtype='object')

# %%
ine_pernoctaciones.columns
# Out:
# Index(['Totales_Territoriales', 'Comunidades_Ciudades_Autonomas', 'Provincia',
#        'Viajeros_Pernoctaciones', 'Residencia', 'Periodo', 'Total',
#        'ID_pernoctaciones'],
#       dtype='object')

# %%
ine_viajeros.columns
# Out:
# Index(['Totales_Territoriales', 'Comunidades_Ciudades_Autonomas', 'Provincia',
#        'Viajeros_Pernoctaciones', 'Residencia', 'Periodo', 'Total',
#        'ID_viajeros'],
#       dtype='object')

# %%
ine_total.columns
# Out:
# Index(['Totales_Territoriales', 'Comunidades_Ciudades_Autonomas',
#        'Viajeros_Pernoctaciones', 'Residencia', 'Periodo', 'Total',
#        'ID_viajeros', 'ID_pernoctaciones', 'ID_total'],
#       dtype='object')

# %%
ign.columns
# Out:
# Index(['Capital', 'Provincia', 'Población', 'Latitud', 'Longitud',
#        'ID_latitud_longitud'],
#       dtype='object')

# %%
# Visualización de la distribución de la temperatura media
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
sns.histplot(clima['Media_tmed'], kde=True, color='skyblue')
plt.title('Distribución de Temperatura Media')

plt.subplot(1, 2, 2)
sns.boxplot(x='Periodo', y='Media_tmed', data=clima, palette='viridis')
plt.title('Variación de Temperatura Media a lo largo del Tiempo')

plt.tight_layout()
plt.show();
# Out:
# C:\Users\carol\AppData\Local\Temp\ipykernel_26700\1345401194.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Periodo', y='Media_tmed', data=clima, palette='viridis')

# %%
ine_pernoctaciones[['Viajeros_Pernoctaciones', 'Total']].describe().T
# Out:
#          count       mean            std  min       25%      50%        75%  \
# Total  17550.0  321199.38  825188.343536  0.0  30991.25  80065.0  234773.25
#
#               max
# Total  11045064.0

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x='Periodo', y='Viajeros_Pernoctaciones', hue='Provincia', data=ine_pernoctaciones, palette='viridis')
plt.title('Variación de Pernoctaciones a lo largo del Tiempo y por Provincia')
plt.show();
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 2
#       1 plt.figure(figsize=(12, 6))
# ----> 2 sns.lineplot(x='Periodo', y='Viajeros_Pernoctaciones', hue='Provincia', data=ine_pernoctaciones, palette='viridis')
#       3 plt.title('Variación de Pernoctaciones a lo largo del Tiempo y por Provincia')
#       4 plt.show();
#
# File ~\anaconda3\envs\clima\Lib\site-packages\seaborn\relational.py:507, in lineplot(data, x, y, hue, size, style, units, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     504 color = kwargs.pop("color", kwargs.pop("c", None))
#     505 kwargs["color"] = _default_color(ax.plot, hue, color, kwargs)
# --> 507 p.plot(ax, kwargs)
#     508 return ax
#
# ...

# %%
ine_viajeros[['Viajeros_Pernoctaciones', 'Total']].describe().T
# Out:
#          count           mean            std  min       25%      50%  \
# Total  17550.0  100736.148433  179585.440321  0.0  17451.75  43088.5
#
#              75%        max
# Total  102686.25  1954444.0

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x='Periodo', y='Viajeros_Pernoctaciones', hue='Provincia', data=ine_viajeros, palette='viridis')
plt.title('Variación de Viajeros a lo largo del Tiempo y por Provincia')
plt.show();

# %%
ine_total[['Total']].describe().T
# Out:
#          count          mean           std  min       25%       50%       75%  \
# Total  14040.0  1.055955e+06  3.298363e+06  0.0  40712.25  166514.0  610995.5
#
#               max
# Total  47059511.0

# %%
plt.figure(figsize=(10, 8))
sns.scatterplot(x='Viajeros_Pernoctaciones', y='Total', data=ine_total, hue='Provincia', palette='viridis')
plt.title('Relación entre Viajeros y Pernoctaciones por Provincia')
plt.show();

# %%
# Visualización de la distribución de la población
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
sns.histplot(ign['Población'], kde=True, color='gold')
plt.title('Distribución de la Población')

# Diagrama de dispersión geoespacial
plt.subplot(1, 2, 2)
sns.scatterplot(x='Longitud', y='Latitud', size='Población', data=ign, palette='viridis')
plt.title('Diagrama de Dispersión Geoespacial de la Población')
plt.show();
